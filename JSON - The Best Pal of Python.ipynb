# %%
# !pip install numpy==1.16.4

import json
import os
import pandas as pd
import ast
import numpy as np

cwd = os.getcwd()
files = os.listdir(cwd)
cwd
# Out:
# Requirement already satisfied: numpy==1.16.4 in ./anaconda/lib/python3.6/site-packages (1.16.4)
# '/Users/sanduhr'

# %%
db = json.load(open('Desktop/test.json'))
len(db)
# Out:
# 1327

# %%
# explore the data type
db_address = db[0][13][0]
print(db_address)
print (type(db_address))

# Transform string to dictionary
import ast 
db_address_res = ast.literal_eval(db_address)
print(db_address_res)
print (type(db_address_res))
# Out:
# {"address": "4509 BELAIR ROAD", "city": "Baltimore", "state": "MD", "zip": ""}
# <class 'str'>
# {'address': '4509 BELAIR ROAD', 'city': 'Baltimore', 'state': 'MD', 'zip': ''}
# <class 'dict'>

# %%
#iteration for all the address in the json data

rec = 0
db_address_res_1 = []
restaurant_address_df = pd.DataFrame()
for rec in range(len(db)):
    
    db_address_res_1= ast.literal_eval(db[rec][13][0]) 

    
    restaurant_address_df_1 = pd.DataFrame(db_address_res_1,index = [db[rec][0]])
    
   
    restaurant_address_df = restaurant_address_df.append(restaurant_address_df_1)

print (restaurant_address_df['address'][0])
# Out:
# 4509 BELAIR ROAD

# %%
# Create a new column to combine the columns 'address', 'city' and 'state' to a new column 'completeAddress'

restaurant_address_df['completeAddress'] = restaurant_address_df[restaurant_address_df.columns[0:3]].apply(lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)
restaurant_address_df['completeAddress'][1]
# Out:
# '1919 FLEET ST,Baltimore,MD'

# %%
# Test data - Fetch the location and coordinates of an address from Google Geo
from geopy.geocoders import Nominatim
locator = Nominatim(user_agent= 'sanduhr06@gmail.com')

for i in range(16):
    location = locator.geocode(restaurant_address_df['completeAddress'][i])
location
# Out:
# Location(Biddle Street, Maryland Manor, Rosedale, Baltimore County, Maryland, 21237, United States of America, (39.3097142, -76.5252203, 0.0))

# %%
from geopy.geocoders import Nominatim
locator = Nominatim(user_agent= 'sanduhr06@gmail.com')

temp_geo = pd.DataFrame() 
geo_2 = pd.DataFrame()

for i in range(len(db)):
    
    location = locator.geocode(restaurant_address_df['completeAddress'][i])
    if not location:
        Latitude = 'Na'
        Longitude = 'Na'
        data = {'Latitude':['Na'],'Langitute':['Na'] }
        temp_geo = pd.DataFrame(data,index =[db[i][0]])
        geo_2 = geo_2.append(temp_geo)
    else:
        Latitude = location.latitude
        Longitude = location.longitude
        data = {'Latitude':[Latitude],'Langitute':[Longitude] }
        temp = pd.DataFrame(data,index =[db[i][0]])
        geo_2 = geo_2.append(temp_geo)

# %%
new_restaurant_df = restaurant_address_df.join(geo_2)
new_restaurant_df
# Out:
#                                  address       city state zip  \
# row-235b_tziq-hn7a          201 PRATT ST  Baltimore    MD
# row-23dh_mcyc~ekmn  5440 REISTERSTOWN RD  Baltimore    MD
# row-2444.462m.vzxw    11 MOUNT VERNON PL  Baltimore    MD
# row-24qc-9esk.kd8s        2400 BOSTON ST  Baltimore    MD
# row-25qg_ufkq.hz24     438 BELVEDERE AVE  Baltimore    MD
# row-26he.akkb~t5w4  7000 REISTERSTOWN RD  Baltimore    MD
# row-26tb-ckky-3ndp      401 MONTFORD AVE  Baltimore    MD
# row-28ex_zssi_g8aq      414 BALTIMORE ST  Baltimore    MD
# row-29u4-4nrq~6w7w        5860 BELAIR RD  Baltimore    MD
# row-2aa3_3rph-47p7          601 FORT AVE  Baltimore    MD
# row-2aze_9b4e.dxiw         3820 PRATT ST  Baltimore    MD
# row-2aze_9b4e.dxiw         3820 PRATT ST  Baltimore    MD
# row-2aze_9b4e.dxiw         3820 PRATT ST  Baltimore    MD
# row-2aze_9b4e.dxiw         3820 PRATT ST  Baltimore    MD
# row-2aze_9b4e.dxiw         3820 PRATT ST  Baltimore    MD
# row-2aze_9b4e.dxiw         3820 PRATT ST  Baltimore    MD
# row-2aze_9b4e.dxiw         3820 PRATT ST  Baltimore    MD
# row-2aze_9b4e.dxiw         3820 PRATT ST  Baltimore    MD
# row-2aze_9b4e.dxiw         3820 PRATT ST  Baltimore    MD
# row-2aze_9b4e.dxiw         3820 PRATT ST  Baltimore    MD
# row-2cea~76fs_734w      2510 GARRETT AVE  Baltimore    MD
# row-2cn3~mbbz.kcpd   1318 GREENMOUNT AVE  Baltimore    MD
# row-2cv4-4uru.hzen     3563 FAIRFIELD RD  Baltimore    MD
# row-2cwg-qisu~gkcc        120 LOMBARD ST  Baltimore    MD
# row-2cwg-qisu~gkcc        120 LOMBARD ST  Baltimore    MD
# row-2e8m_tndf~j6by      2003 PRESBURY ST  Baltimore    MD
# row-2eb8-cws3~9izf        8 BALTIMORE ST  Baltimore    MD
# row-2euh_t9u8~hhsu      237 MONTFORD AVE  Baltimore    MD
# row-2euh_t9u8~hhsu      237 MONTFORD AVE  Baltimore    MD
# row-2euh_t9u8~hhsu      237 MONTFORD AVE  Baltimore    MD
# ...                                  ...        ...   ...  ..
# row-zjp3.xkbq~c8b9     2901 O DONNELL ST  Baltimore    MD
# row-zk8w_fyem_qj7i         1301 PRATT ST  Baltimore    MD
# row-zkri_f29a.8qc3        222 ST PAUL PL  Baltimore    MD
# row-zkzz.4dei-dzgv           204 HIGH ST  Baltimore    MD
# row-zmq4.s3kx.z6zd          1000 HULL ST  Baltimore    MD
# row-zmu7~ibcg_xppk       1105 CHARLES ST  Baltimore    MD
# row-znxy-3fsv.9yfv          301 LIGHT ST  Baltimore    MD
# row-zpvg-qswk.bemp          644 FORT AVE  Baltimore    MD
# row-zrxt_itzz.mi8s         335 NORTH AVE  Baltimore    MD
# row-zs98~v2ex~fdps     500 COLDSPRING LN  Baltimore    MD
# row-zs98~v2ex~fdps     500 COLDSPRING LN  Baltimore    MD
# row-zs98~v2ex~fdps     500 COLDSPRING LN  Baltimore    MD
# row-zscd_2z6n-vv3y          621 PRATT ST  Baltimore    MD
# row-zspf.5udp_xh3z       1015 CHARLES ST  Baltimore    MD
# row-ztgf~acwg~bm8i        829 CHARLES ST  Baltimore    MD
# row-ztxy~r9j8_rfjs          921 FORT AVE  Baltimore    MD
# row-zu26_k4zr~6z94       4526 ERDMAN AVE  Baltimore    MD
# row-zu83~hgkk-u7fh        1730 THAMES ST  Baltimore    MD
# row-zwj8.p59f-3gf5         2401 CHASE ST  Baltimore    MD
# row-zwjn~r2q6_f8mf          601 PRATT ST  Baltimore    MD
# row-zwjn~r2q6_f8mf          601 PRATT ST  Baltimore    MD
# row-zwwv_putf_4rhy    3700 SAN MARTIN DR  Baltimore    MD
# row-zx48_ah5p-8ke9       400 SARATOGA ST  Baltimore    MD
# row-zxsq.d9h7-wmhv       2501 CHARLES ST  Baltimore    MD
# row-zye8~7wbv_72fz  2351 WASHINGTON BLVD  Baltimore    MD
# row-zz5c-aqq6.iszn    4725 GWYNN OAK AVE  Baltimore    MD
# row-zznj~7yry~tjzz         1016 LIGHT ST  Baltimore    MD
# row-zzyb.26yv-6yuq        700 POTOMAC ST  Baltimore    MD
# row-zzyb.26yv-6yuq        700 POTOMAC ST  Baltimore    MD
# row-zzyb.26yv-6yuq        700 POTOMAC ST  Baltimore    MD
#
#                                       completeAddress Langitute Latitude
# row-235b_tziq-hn7a          201 PRATT ST,Baltimore,MD        Na       Na
# row-23dh_mcyc~ekmn  5440 REISTERSTOWN RD,Baltimore,MD       NaN      NaN
# row-2444.462m.vzxw    11 MOUNT VERNON PL,Baltimore,MD       NaN      NaN
# row-24qc-9esk.kd8s        2400 BOSTON ST,Baltimore,MD       NaN      NaN
# row-25qg_ufkq.hz24     438 BELVEDERE AVE,Baltimore,MD        Na       Na
# row-26he.akkb~t5w4  7000 REISTERSTOWN RD,Baltimore,MD       NaN      NaN
# row-26tb-ckky-3ndp      401 MONTFORD AVE,Baltimore,MD        Na       Na
# row-28ex_zssi_g8aq      414 BALTIMORE ST,Baltimore,MD       NaN      NaN
# row-29u4-4nrq~6w7w        5860 BELAIR RD,Baltimore,MD       NaN      NaN
# row-2aa3_3rph-47p7          601 FORT AVE,Baltimore,MD       NaN      NaN
# row-2aze_9b4e.dxiw         3820 PRATT ST,Baltimore,MD        Na       Na
# row-2aze_9b4e.dxiw         3820 PRATT ST,Baltimore,MD        Na       Na
# row-2aze_9b4e.dxiw         3820 PRATT ST,Baltimore,MD        Na       Na
# row-2aze_9b4e.dxiw         3820 PRATT ST,Baltimore,MD        Na       Na
# row-2aze_9b4e.dxiw         3820 PRATT ST,Baltimore,MD        Na       Na
# row-2aze_9b4e.dxiw         3820 PRATT ST,Baltimore,MD        Na       Na
# row-2aze_9b4e.dxiw         3820 PRATT ST,Baltimore,MD        Na       Na
# row-2aze_9b4e.dxiw         3820 PRATT ST,Baltimore,MD        Na       Na
# row-2aze_9b4e.dxiw         3820 PRATT ST,Baltimore,MD        Na       Na
# row-2aze_9b4e.dxiw         3820 PRATT ST,Baltimore,MD        Na       Na
# row-2cea~76fs_734w      2510 GARRETT AVE,Baltimore,MD       NaN      NaN
# row-2cn3~mbbz.kcpd   1318 GREENMOUNT AVE,Baltimore,MD       NaN      NaN
# row-2cv4-4uru.hzen     3563 FAIRFIELD RD,Baltimore,MD       NaN      NaN
# row-2cwg-qisu~gkcc        120 LOMBARD ST,Baltimore,MD        Na       Na
# row-2cwg-qisu~gkcc        120 LOMBARD ST,Baltimore,MD        Na       Na
# row-2e8m_tndf~j6by      2003 PRESBURY ST,Baltimore,MD       NaN      NaN
# row-2eb8-cws3~9izf        8 BALTIMORE ST,Baltimore,MD       NaN      NaN
# row-2euh_t9u8~hhsu      237 MONTFORD AVE,Baltimore,MD        Na       Na
# row-2euh_t9u8~hhsu      237 MONTFORD AVE,Baltimore,MD        Na       Na
# row-2euh_t9u8~hhsu      237 MONTFORD AVE,Baltimore,MD        Na       Na
# ...                                               ...       ...      ...
# row-zjp3.xkbq~c8b9     2901 O DONNELL ST,Baltimore,MD        Na       Na
# row-zk8w_fyem_qj7i         1301 PRATT ST,Baltimore,MD        Na       Na
# row-zkri_f29a.8qc3        222 ST PAUL PL,Baltimore,MD       NaN      NaN
# row-zkzz.4dei-dzgv           204 HIGH ST,Baltimore,MD        Na       Na
# row-zmq4.s3kx.z6zd          1000 HULL ST,Baltimore,MD       NaN      NaN
# row-zmu7~ibcg_xppk       1105 CHARLES ST,Baltimore,MD       NaN      NaN
# row-znxy-3fsv.9yfv          301 LIGHT ST,Baltimore,MD       NaN      NaN
# row-zpvg-qswk.bemp          644 FORT AVE,Baltimore,MD       NaN      NaN
# row-zrxt_itzz.mi8s         335 NORTH AVE,Baltimore,MD       NaN      NaN
# row-zs98~v2ex~fdps     500 COLDSPRING LN,Baltimore,MD        Na       Na
# row-zs98~v2ex~fdps     500 COLDSPRING LN,Baltimore,MD        Na       Na
# row-zs98~v2ex~fdps     500 COLDSPRING LN,Baltimore,MD        Na       Na
# row-zscd_2z6n-vv3y          621 PRATT ST,Baltimore,MD        Na       Na
# row-zspf.5udp_xh3z       1015 CHARLES ST,Baltimore,MD       NaN      NaN
# row-ztgf~acwg~bm8i        829 CHARLES ST,Baltimore,MD       NaN      NaN
# row-ztxy~r9j8_rfjs          921 FORT AVE,Baltimore,MD       NaN      NaN
# row-zu26_k4zr~6z94       4526 ERDMAN AVE,Baltimore,MD       NaN      NaN
# row-zu83~hgkk-u7fh        1730 THAMES ST,Baltimore,MD       NaN      NaN
# row-zwj8.p59f-3gf5         2401 CHASE ST,Baltimore,MD        Na       Na
# row-zwjn~r2q6_f8mf          601 PRATT ST,Baltimore,MD        Na       Na
# row-zwjn~r2q6_f8mf          601 PRATT ST,Baltimore,MD        Na       Na
# row-zwwv_putf_4rhy    3700 SAN MARTIN DR,Baltimore,MD       NaN      NaN
# row-zx48_ah5p-8ke9       400 SARATOGA ST,Baltimore,MD        Na       Na
# row-zxsq.d9h7-wmhv       2501 CHARLES ST,Baltimore,MD       NaN      NaN
# row-zye8~7wbv_72fz  2351 WASHINGTON BLVD,Baltimore,MD       NaN      NaN
# row-zz5c-aqq6.iszn    4725 GWYNN OAK AVE,Baltimore,MD       NaN      NaN
# row-zznj~7yry~tjzz         1016 LIGHT ST,Baltimore,MD       NaN      NaN
# row-zzyb.26yv-6yuq        700 POTOMAC ST,Baltimore,MD        Na       Na
# row-zzyb.26yv-6yuq        700 POTOMAC ST,Baltimore,MD        Na       Na
# row-zzyb.26yv-6yuq        700 POTOMAC ST,Baltimore,MD        Na       Na
#
# [2283 rows x 7 columns]
